# %%
import glob 
import cv2
import sys
from PIL import Image
import pytesseract
import numpy as np

originFolder = "/home/nuc-obs-06/projects/text-detection-ctpn-banjin-dev/text-detection-ctpn-banjin-dev/data/demo"
copyFolder = "/home/nuc-obs-06/projects/Aravind/Test_Samples_Practice/downloads/washington driving license"

font                   = cv2.FONT_HERSHEY_PLAIN
bottomLeftCornerOfText = (30,30)
fontScale              = 1
fontColor              = (255,255,255)
lineType               = 1
for img in glob.glob(originFolder+'/*.*'):
    imageName = img.rsplit('/')[-1]
    print(imageName)
    var_img = cv2.imread(img, cv2.IMREAD_GRAYSCALE)
#     print(var_img)
    (thresh, im_bw) = cv2.threshold(var_img, 127, 255, cv2.THRESH_BINARY)
    cv2.imshow("original image" , var_img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
#     print("coomon")
#     output = pytesseract.image_to_string(Image.fromarray(im_bw))
#     print(output)
    
#     (thresh, im_bw) = cv2.threshold(var_img, 127,255,cv2.THRESH_BINARY)
#     cv2.imshow("THRESH_BINARY" , im_bw)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
#     print("THRESH_BINARY")
#     output = pytesseract.image_to_string(Image.fromarray(im_bw))
#     print(output)
    
#     (thresh, im_bw) = cv2.threshold(var_img, 127,255,cv2.THRESH_BINARY_INV)
#     cv2.imshow("THRESH_BINARY_INV" , im_bw)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
#     print("THRESH_BINARY_INV")
#     output = pytesseract.image_to_string(Image.fromarray(im_bw))
#     print(output)
    
#     (thresh, im_bw) = cv2.threshold(var_img, 127,255,cv2.THRESH_TRUNC)
#     cv2.imshow("THRESH_TRUNC" , im_bw)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
#     print("THRESH_TRUNC")
#     output = pytesseract.image_to_string(Image.fromarray(im_bw))
#     print(output)
    
#     (thresh, im_bw) = cv2.threshold(var_img, 127,255,cv2.THRESH_TOZERO)
#     cv2.imshow("THRESH_TOZERO" , im_bw)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
#     print("THRESH_TOZERO")
#     output = pytesseract.image_to_string(Image.fromarray(im_bw))
#     print(output)
    
#     (thresh, im_bw) = cv2.threshold(var_img, 127,255,cv2.THRESH_TOZERO_INV)
#       cv2.imshow("Original Image" , im_bw)
#       cv2.waitKey(0)
#       cv2.destroyAllWindows()
#     print("THRESH_TOZERO_INV")
#     output = pytesseract.image_to_string(Image.fromarray(im_bw))
#     print(output)
    
    output = pytesseract.image_to_string(Image.fromarray(im_bw))
    print(output)
#     break
#     outArray = output.rsplit('\n')
#     offset = 30
#     x,y = 25,30
#     outputBoxImg =  np.zeros((600,512,3), np.uint8)
#     temp = 0
#     for idx,data in enumerate(outArray):
#         if str(data):
#             temp = temp + 1
#             cv2.putText(outputBoxImg,str(data), 
#             (x,y+offset*temp), 
#             font, 
#             fontScale,
#             fontColor,
#             lineType)
#     cv2.imshow("Output Image",outputBoxImg)
#     originImage =  cv2.imread(originFolder+"/"+imageName)
    
#     cv2.imshow("Original Image" , var_img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    

print("All Images displayed")
# Out:
# org_florida_07.jpg
# Ke
# #04...
# 5 Pegouana
#
#
#
# a
# All Images displayed
