# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import pytesseract
import os

inputFolder = "/home/nuc-obs-06/projects/Aravind/Test_Samples_Practice/us_samples/DataSets/original_dataset/canada"
config = ('-l eng --oem 1 --psm 3')
for image in os.listdir(inputFolder):
    
    img = cv2.imread(inputFolder+"/"+image)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    (thresh, img) = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
    cv2.imshow("original Image",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    output = pytesseract.image_to_string(Image.fromarray(img))
    print("Tesseract Output ",output)
    print("###########################################")
# Out:
# Tesseract Output  H0288 - 74075-11206 -
# _ 2019/01/07 4b EXP/ EXP. ~ 2020/1 2/06
# GH0462289. ss teHGT/HaUT. 173.cm
# ###########################################
# Tesseract Output  woe oop oe tt : Do oe
# le Ce nt, rare oan sy . . o. wat,
# = “LDWEZ ¢ CWRRAME A+ SERGE IOS S TEP MANTLOPEZ + CRERANTAS SERGIOOSTEFMANALOPET* CARR O° ||
#
# ed 7 COND.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# S2NAMEINOM oO "Valid Driver's |
# LOPEZ CARRANZA, On
# SERGIO,STEFHAN | Photo de permi
#
# 8 23 GOTHAM CRT | valide de!’ Onte
#
# clr Ee -
#
# _ TORONTO, ON, M6M 2N9
# 4d NUMBER’
# NUMERO L6531 - 70089 - 40705
# (Aa ISSIDEL, = 2018/08/21 4b EXP EXP, © 2023/08/07
# SDO/REF, GE4723295 = 16HGTINAUT. 178 cm ~
# 15 SEXISEXE Mf ae
#
# 9 CLASS! G2
# CATEG.
#
# ~ 42 REST/
# ###########################################
# Tesseract Output  ck
# S
# $7
#
# éo
# hae
# 6
# Ke?
#
# 4
# *
#
# ms LS
# CIS GERD
# SORES
# (>
# NII
#
# af
#
# x
#
#
#
#
# =e
#
# BRA tPTON, ON, L6Y 485
# DO0776 - 06246 -
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 7102
#
# Ne eK oe Be ee
# ee ee ee te
# a
# 46 HGT/ HAUT. 1 /@ SS
# BE eee Ik ky -
# Ww my a
#
#
#
# ee RO DS
# Naas
#
# Om,
#
# KN
#
# Ee
# ef’ A
# SN
# ###########################################
