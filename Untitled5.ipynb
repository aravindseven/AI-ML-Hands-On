# %%
import cv2
from PIL import Image
import pytesseract
import os

inputImage = "/home/nuc-obs-06/projects/text-detection-ctpn-banjin-dev/text-detection-ctpn-banjin-dev/data/bounded_images/1"
for imgName in os.listdir(inputImage):
    print(imgName)
    img = cv2.imread(inputImage+"/"+imgName)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
#     resized_area = cv2.resize(img, None, fx=0.5, fy=0.5, interpolation=cv2.INTER_AREA)
#     cv2.imshow("Resized Area",resized_area)

    # inter_cubic = cv2.resize(img, None, fx=2, fy=2, interpolation=cv2.INTER_CUBIC)
    # cv2.imshow("INTER_CUBIC",inter_cubic)

    # inter_linear = cv2.resize(img, None, fx=2, fy=2, interpolation=cv2.INTER_LINEAR)
    # cv2.imshow("inter_linear",inter_linear)

    # Blurring

    # avg_blur = cv2.blur(img,(5,5))
    # cv2.imshow("avg_blur",avg_blur)

    # gauus_blurimg = cv2.GaussianBlur(img, (5, 5), 0)
    # cv2.imshow("gauus_blurimg",gauus_blurimg)

    # m_blur = cv2.medianBlur(img, 3)
    # cv2.imshow("medianBlur",m_blur)

    # bl_blur = cv.bilateralFilter(img,9,75,75)
    # cv2.imshow("bilateralFilter",bl_blur)


    #Threshold

    (thresh, img1) = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
    cv2.imshow("img1",img1)

    # (thresh, img2) = cv2.threshold(img, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]
    # cv2.imshow("img2",img2)

    # img2 = cv2.adaptiveThreshold(img,255,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,11,2)
    # cv2.imshow("immeang3",img2)

    img3 = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
#     cv2.imshow("img3",img3)

    # ret2,th2 = cv2.threshold(img,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    # cv2.imshow("th2",th2)





#     cv2.imshow("original Image",img)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    # output = pytesseract.image_to_string(Image.fromarray(th2))
    # print("Tesseract Output Mean Threshold ",output)
    output = pytesseract.image_to_string(Image.fromarray(img1))
    print("Tesseract Output Gaussian Threshold ",output)
# Out:
# 23florisa.png
# Tesseract Output Gaussian Threshold
# 14florisa.png
# Tesseract Output Gaussian Threshold  EXPIRES: 08-16-2007
# 8florisa.png
# Tesseract Output Gaussian Threshold  T: 5:
# 2florisa.png
# Tesseract Output Gaussian Threshold  SAMPLE
# 4florisa.png
# Tesseract Output Gaussian Threshold  REPLACED: 08-16-2003
# 10florisa.png
# Tesseract Output Gaussian Threshold  beration of a motor vehicle constitutes consent to any sobriety test required by law.
# 17florisa.png
# Tesseract Output Gaussian Threshold
# 16florisa.png
# Tesseract Output Gaussian Threshold
# 7florisa.png
# Tesseract Output Gaussian Threshold  REST: BF
# 15florisa.png
# Tesseract Output Gaussian Threshold
# 12florisa.png
# Tesseract Output Gaussian Threshold  JOSEPH A
# 20florisa.png
# Tesseract Output Gaussian Threshold
# 18florisa.png
# Tesseract Output Gaussian Threshold
# 21florisa.png
# Tesseract Output Gaussian Threshold
# 6florisa.png
# Tesseract Output Gaussian Threshold  Sistine SGnte%
# 1florisa.png
# Tesseract Output Gaussian Threshold
# 22florisa.png
# Tesseract Output Gaussian Threshold  Valente lem
# 19florisa.png
# Tesseract Output Gaussian Threshold  DRIVER LICENSE CLASS E
# 9florisa.png
# Tesseract Output Gaussian Threshold
# 3florisa.png
# Tesseract Output Gaussian Threshold  [DA]
# 13florisa.png
# Tesseract Output Gaussian Threshold  DOB: 08-16-1980 SEX: Ma
# 5florisa.png
# Tesseract Output Gaussian Threshold  3456 SOMEWHERE AVE
# 24florisa.png
# Tesseract Output Gaussian Threshold  [s#|W426-545-30-761-0
# 11florisa.png
# Tesseract Output Gaussian Threshold  SAFE ORIVER MOTORCYCLE ONLY 943.0435, F.{

# %%
# Out:
# Tesseract Output Gaussian Threshold
