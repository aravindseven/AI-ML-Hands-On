# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import pytesseract
import os

inputFolder = "/home/nuc-obs-06/projects/text-detection-ctpn-banjin-dev/text-detection-ctpn-banjin-dev/data/bounded_images"
config = ('-l eng --oem 1 --psm 3')
for image in os.listdir(inputFolder):
    
    img = cv2.imread(inputFolder+"/"+image)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    (thresh, img) = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
    cv2.imshow("original Image",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    borderImage = np.zeros([1024,1024],dtype=np.uint8)
    borderImage.fill(255) # or img[:] = 255
#     cv2.imshow("white image",borderImage)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    x_offset = 30
    y_offset = 50
    borderImage[y_offset:y_offset+img.shape[0], x_offset:x_offset+img.shape[1]] = img
    cv2.imshow("Overlayed image",borderImage)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    output = pytesseract.image_to_string(Image.fromarray(borderImage))
    print("Tesseract Output ",output)
    output = pytesseract.image_to_string(borderImage)
    print("Tesseract Output ",output)
    output = pytesseract.image_to_string(borderImage, config=config)
    print("Tesseract Output ",output)
# Out:
# Tesseract Output  W426-545-30-761-0)
# Tesseract Output  W426-545-30-761-0)
# Tesseract Output  W426-545-30-761-0)
# Tesseract Output  Operation of a motor vehicle constitutes Consent to any sobriety test required by law.
# Tesseract Output  Operation of a motor vehicle constitutes Consent to any sobriety test required by law.
# Tesseract Output  Operation of a motor vehicle constitutes Consent to any sobriety test required by law.
# Tesseract Output  TALLAHASSEE. FL 32399
# Tesseract Output  TALLAHASSEE. FL 32399
# Tesseract Output  TALLAHASSEE. FL 32399
# Tesseract Output  ISSUED: 07-49-2011
# Tesseract Output  ISSUED: 07-49-2011
# Tesseract Output  ISSUED: 07-49-2011
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  ENDORSE: X
# Tesseract Output  ENDORSE: X
# Tesseract Output  ENDORSE: X
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  008: 07-11-1980 SEX: M |
# Tesseract Output  008: 07-11-1980 SEX: M |
# Tesseract Output  008: 07-11-1980 SEX: M |
# Tesseract Output  EXPIRES: 07410-2019
# Tesseract Output  EXPIRES: 07410-2019
# Tesseract Output  EXPIRES: 07410-2019
# Tesseract Output  ORGAN DONOR
# Tesseract Output  ORGAN DONOR
# Tesseract Output  ORGAN DONOR
# Tesseract Output  3456 SOMEWHERE AVE
# Tesseract Output  3456 SOMEWHERE AVE
# Tesseract Output  3456 SOMEWHERE AVE
# Tesseract Output  REST: BF
# Tesseract Output  REST: BF
# Tesseract Output  REST: BF
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  “Sample
# Tesseract Output  “Sample
# Tesseract Output  “Sample
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  IVER LIC
# Tesseract Output  IVER LIC
# Tesseract Output  IVER LIC
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  JASON
# Tesseract Output  JASON
# Tesseract Output  JASON

# %%
inputFolder = "/home/nuc-obs-06/projects/text-detection-ctpn-banjin-dev/text-detection-ctpn-banjin-dev/data/bounded_images"
config = ('-l eng --oem 1 --psm 3')
for image in os.listdir(inputFolder):
    
    img = cv2.imread(inputFolder+"/"+image)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    (thresh, img) = cv2.threshold(img, 127, 255, cv2.THRESH_BINARY)
    cv2.imshow("original Image",img)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    borderImage = np.zeros([1024,1024],dtype=np.uint8)
    borderImage.fill(255) # or img[:] = 255
#     cv2.imshow("white image",borderImage)
#     cv2.waitKey(0)
#     cv2.destroyAllWindows()
    x_offset = 30
    y_offset = 50
    borderImage[y_offset:y_offset+img.shape[0], x_offset:x_offset+img.shape[1]] = img
    cv2.imshow("Overlayed image",borderImage)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    output = pytesseract.image_to_string(Image.fromarray(borderImage))
    print("Tesseract Output ",output)
    output = pytesseract.image_to_string(borderImage)
    print("Tesseract Output ",output)
    output = pytesseract.image_to_string(borderImage, config=config)
    print("Tesseract Output ",output)
# Out:
# Tesseract Output  W426-545-30-761-0)
# Tesseract Output  W426-545-30-761-0)
# Tesseract Output  W426-545-30-761-0)
# Tesseract Output  Operation of a motor vehicle constitutes Consent to any sobriety test required by law.
# Tesseract Output  Operation of a motor vehicle constitutes Consent to any sobriety test required by law.
# Tesseract Output  Operation of a motor vehicle constitutes Consent to any sobriety test required by law.
# Tesseract Output  TALLAHASSEE. FL 32399
# Tesseract Output  TALLAHASSEE. FL 32399
# Tesseract Output  TALLAHASSEE. FL 32399
# Tesseract Output  ISSUED: 07-49-2011
# Tesseract Output  ISSUED: 07-49-2011
# Tesseract Output  ISSUED: 07-49-2011
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  ENDORSE: X
# Tesseract Output  ENDORSE: X
# Tesseract Output  ENDORSE: X
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  008: 07-11-1980 SEX: M |
# Tesseract Output  008: 07-11-1980 SEX: M |
# Tesseract Output  008: 07-11-1980 SEX: M |
# Tesseract Output  EXPIRES: 07410-2019
# Tesseract Output  EXPIRES: 07410-2019
# Tesseract Output  EXPIRES: 07410-2019
# Tesseract Output  ORGAN DONOR
# Tesseract Output  ORGAN DONOR
# Tesseract Output  ORGAN DONOR
# Tesseract Output  3456 SOMEWHERE AVE
# Tesseract Output  3456 SOMEWHERE AVE
# Tesseract Output  3456 SOMEWHERE AVE
# Tesseract Output  REST: BF
# Tesseract Output  REST: BF
# Tesseract Output  REST: BF
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  “Sample
# Tesseract Output  “Sample
# Tesseract Output  “Sample
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  IVER LIC
# Tesseract Output  IVER LIC
# Tesseract Output  IVER LIC
# Tesseract Output
# Tesseract Output
# Tesseract Output
# Tesseract Output  JASON
# Tesseract Output  JASON
# Tesseract Output  JASON
