# %%
import cv2
import numpy as np

var_img = cv2.imread('/home/nuc-obs-06/projects/text-detection-ctpn-banjin-dev/text-detection-ctpn-banjin-dev/data/res/5.2008front.jpg')
print(var_img)
# crop_img = var_img[60:111, 96:768]
# 336 263 640 263 640 303 336 303
# 32,477,
# 416,477,
# 416,525,
# 32,525
# 96,60,768,60,768,111,96,111,
# print("crooped image")
# print(crop_img)
points =np.array([[[336, 263]],

       [[640, 263]],

       [[640, 303]],

       [[336, 303]]])

rect = cv2.boundingRect(points)
x,y,w,h = rect
cv2.rectangle(var_img, (x, y), (x+w, y+h), (0,0,255), 2)
cv2.imshow('image',var_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# 336,263,640,263,640,303,336,303
# crop_img = var_img[178:190, 336:297]
# crop_img = var_img[263:303, 336:640]
# # 176,105,416,105,416,143,176,143,0.9997428
# # print(crop_img)
# cv2.imshow('image',crop_img)
# cv2.waitKey(0)
# cv2.destroyAllWindows()
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]
